# %%
import math
from datetime import datetime
import json
from pymongo import MongoClient
import dbQueries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
sns.set()

# %%
plt.style.use('seaborn-notebook')

# %%
# Display results per genre
re_json = dbQueries.getTopGenres(10)
df_topGenres = pd.DataFrame.from_dict(re_json)
df_topGenres
# Out:
#         genres  avgRuntime  noMovies  avgPopularity  avgVotes    avgBudget  \
# 0        Drama      96.347       956         19.010     5.588   813482.722
# 1       Comedy      87.180       685         26.209     5.631  1461973.926
# 2     Thriller      87.952       504         24.640     5.287   748302.462
# 3  Documentary     177.715       466          6.830     5.276    12958.429
# 4       Horror      83.267       460         23.032     4.967   679186.528
# 5      Romance      89.464       371         16.142     5.657   170811.412
# 6       Action      90.824       262         45.134     5.414  3954561.317
# 7     TV Movie      76.801       211          7.810     6.261     9479.498
# 8       Family      76.649       171         66.763     6.401  6278134.930
# 9        Crime      94.043       163         17.153     5.455   472388.669
#
#     avgRevenue
# 0  1303498.104
# 1  1533509.747
# 2   962270.169
# 3      371.322
# 4  1070580.291
# 5   244221.159
# 6  6134759.863
# 7        0.000
# 8  5851886.099
# 9   323253.920

# %%
df_topGenres.shape
# Out:
# (10, 7)

# %%
df_topGenres.describe()
# Out:
#        avgRuntime    noMovies  avgPopularity   avgVotes     avgBudget  \
# count   10.000000   10.000000      10.000000  10.000000  1.000000e+01
# mean    96.024200  424.900000      25.272300   5.593700  1.460128e+06
# std     29.436468  251.030963      18.122465   0.439916  2.049573e+06
# min     76.649000  163.000000       6.830000   4.967000  9.479498e+03
# 25%     84.245250  223.750000      16.394750   5.318750  2.462057e+05
# 50%     88.708000  415.500000      21.021000   5.521500  7.137445e+05
# 75%     93.238250  494.500000      25.816750   5.650500  1.299851e+06
# max    177.715000  956.000000      66.763000   6.401000  6.278135e+06
#
#          avgRevenue
# count  1.000000e+01
# mean   1.742435e+06
# std    2.304731e+06
# min    0.000000e+00
# 25%    2.639793e+05
# 50%    1.016425e+06
# 75%    1.476007e+06
# max    6.134760e+06

# %%
# Checking for null values
df_topGenres.isnull().sum()
# Out:
# genres           0
# avgRuntime       0
# noMovies         0
# avgPopularity    0
# avgVotes         0
# avgBudget        0
# avgRevenue       0
# dtype: int64

# %%
# Checking for duplications
sum(df_topGenres.duplicated())
#df.drop_duplicates(inplace=True)
# Out:
# 0

# %%
# avgBudget and avgRevenue
# Replace the value of '0' to NaN
df_topGenres[['avgBudget','avgRevenue']] = df_topGenres[['avgBudget','avgRevenue']].replace(0,np.NAN)

df_topGenres.dropna(subset=['avgBudget', 'avgRevenue'], inplace=True)
print('After cleaning, we have {} rows'.format(df_topGenres.shape[0]))
# Out:
# After cleaning, we have 9 rows

# %%
# Profits of each movie
df_topGenres['avgProfit'] = df_topGenres['avgRevenue']-df_topGenres['avgBudget']
df_topGenres['avgProfit'] = df_topGenres['avgProfit'].apply(np.int64)
df_topGenres['avgBudget'] = df_topGenres['avgBudget'].apply(np.int64)
df_topGenres['avgRevenue'] = df_topGenres['avgRevenue'].apply(np.int64)
df_topGenres['avgRuntime'] = df_topGenres['avgRuntime'].apply(np.int64)
df_topGenres['avgVotes'] = df_topGenres['avgVotes'].apply(np.int64)

df_topGenres.head()
# Out:
#         genres  avgRuntime  noMovies  avgPopularity  avgVotes  avgBudget  \
# 0        Drama          96       956         19.010         5     813482
# 1       Comedy          87       685         26.209         5    1461973
# 2     Thriller          87       504         24.640         5     748302
# 3  Documentary         177       466          6.830         5      12958
# 4       Horror          83       460         23.032         4     679186
#
#    avgRevenue  avgProfit
# 0     1303498     490015
# 1     1533509      71535
# 2      962270     213967
# 3         371     -12587
# 4     1070580     391393

# %%
df_topGenres.dtypes
# Out:
# genres            object
# avgRuntime         int64
# noMovies           int64
# avgPopularity    float64
# avgVotes           int64
# avgBudget          int64
# avgRevenue         int64
# avgProfit          int64
# dtype: object

# %%
my_colors = 'rgbkymc'
genres = df_topGenres['genres']
avgBudget = df_topGenres['avgBudget']
plt.barh(genres, avgBudget, color= my_colors)

plt.title("Average Budget For Each Genres")
plt.xlabel("Average Budget")    
plt.tight_layout()
plt.show()

# %%
plt.style.use('seaborn-notebook')
genres = df_topGenres['genres']
avgProfit = df_topGenres['avgProfit']
plt.barh(genres, avgProfit)

plt.title("Average Profit For Each Genres")
plt.xlabel("Average Profit")    
plt.tight_layout()
plt.show()

# %%
# Display results per production companies
re_json = dbQueries.getTopProductionCompanies(10)
df_topCompanies = pd.DataFrame.from_dict(re_json)
df_topCompanies.head(5)
# Out:
#     production_companies  noMovies  avgPopularity  avgVotesNo     avgBudget  \
# 0  HBO Documentary Films        20         12.498       9.150  0.000000e+00
# 1             Rai Cinema        17          5.825      83.353  0.000000e+00
# 2         Amazon Studios        17         43.813     165.412  0.000000e+00
# 3   Walt Disney Pictures        14        239.847    1125.143  5.314286e+07
# 4        Ingenious Media        13         47.846     171.538  8.769231e+06
#
#      avgRevenue  avgVotes
# 0  0.000000e+00     6.090
# 1  0.000000e+00     6.265
# 2  0.000000e+00     6.076
# 3  1.828517e+07     7.407
# 4  3.091637e+06     6.408

# %%
#plt.style.use('fast')
company = df_topCompanies['production_companies']
avgBudget = df_topCompanies['avgBudget']
plt.barh(company, avgBudget)           #Important changing

plt.xscale('log')
plt.title("Average Budget For Each Compnay")
plt.xlabel("Average Budget")    
plt.tight_layout()
plt.show()

# %%
# Display results per vote average
re_json = dbQueries.getTopVoteAvg(10)
df_topVoted = pd.DataFrame.from_dict(re_json)
df_topVoted.head(5)
# Out:
#            title                                genres     budget  popularity  \
# 0       Captured                    [Thriller, Horror]          0       3.062
# 1  The Last Bite     [Mystery, Science Fiction, Drama]          0       5.157
# 2      Вторжение                     [Science Fiction]    8819200      51.966
# 3       Dolittle  [Family, Comedy, Fantasy, Adventure]  175000000      52.025
# 4      Les vétos                       [Comedy, Drama]          0       5.500
#
#                                 production_companies  \
# 0                                                 []
# 1                                                 []
# 2  [Cinema Fund, Art Pictures Studio, Vodorod Fil...
# 3  [Universal Pictures, Team Downey, Perfect Worl...
# 4                [Les Films du 24, UGC Distribution]
#
#                                 production_countries    revenue  runtime  \
# 0                         [United States of America]          0        0
# 1                                   [United Kingdom]          0       70
# 2                                           [Russia]   32104054      129
# 3  [United Kingdom, China, United States of Ameri...  245692007      101
# 4                                           [France]          0       92
#
#      status  vote_avg  vote_count
# 0  Released      10.0           1
# 1  Released       7.0           2
# 2  Released       6.9         475
# 3  Released       6.8        2399
# 4  Released       6.8          50

# %%
# Display results per revenue
re_json = dbQueries.getTopMoreRevenue(10)
df_topMoreRevenue = pd.DataFrame.from_dict(re_json)
df_topMoreRevenue.head(5)
# Out:
#            title                                genres     budget  popularity  \
# 0       Dolittle  [Family, Comedy, Fantasy, Adventure]  175000000      52.025
# 1      Tolo Tolo               [Comedy, Drama, Family]   20000000      10.207
# 2      Вторжение                     [Science Fiction]    8819200      51.966
# 3     La Llorona                    [Thriller, Horror]          0       9.617
# 4  Ghost Stories                              [Horror]          0       8.424
#
#                                 production_companies  \
# 0  [Universal Pictures, Team Downey, Perfect Worl...
# 1                         [Taodue Film, Medusa Film]
# 2  [Cinema Fund, Art Pictures Studio, Vodorod Fil...
# 3                                                 []
# 4        [RSVP Movies, Flying Unicorn Entertainment]
#
#                                 production_countries    revenue  runtime  \
# 0  [United Kingdom, China, United States of Ameri...  245692007      101
# 1                                            [Italy]   52186426       90
# 2                                           [Russia]   32104054      129
# 3                                           [Mexico]          0        0
# 4                                            [India]          0      144
#
#      status  vote_avg  vote_count
# 0  Released       6.8        2399
# 1  Released       6.2         867
# 2  Released       6.9         475
# 3  Released       6.0           2
# 4  Released       4.7          38

# %% [markdown]
# # Analysis On Whole Data Set

# %%
re_json = dbQueries.wholeData()
wholeData = pd.DataFrame.from_dict(re_json)
wholeData.head()
# Out:
#                                    title  \
# 0             Gabriel's Inferno Part III
# 1  Las tres muertes de Marisela Escobedo
# 2                          블랙핑크: 세상을 밝혀라
# 3              Gabriel's Inferno Part II
# 4                            Wolfwalkers
#
#                                     genres  budget  popularity  \
# 0                        [Romance, Comedy]       0      31.807
# 1                     [Documentary, Crime]       0      25.614
# 2                     [Documentary, Music]       0      17.153
# 3                                [Romance]       0       8.021
# 4  [Family, Adventure, Animation, Fantasy]       0      39.483
#
#                                 production_companies  \
# 0                                      [PassionFlix]
# 1                                                 []
# 2                                     [RadicalMedia]
# 3                                      [PassionFlix]
# 4  [Cartoon Saloon, Melusine Productions, Value&P...
#
#             production_countries  revenue  runtime    status  vote_avg  \
# 0     [United States of America]        0      105  Released       9.0
# 1                       [Mexico]        0      109  Released       9.0
# 2                  [South Korea]        0       79  Released       8.9
# 3                             []        0      105  Released       8.8
# 4  [France, Ireland, Luxembourg]   171900      103  Released       8.8
#
#    vote_count release_date
# 0         652   2020-11-19
# 1         133   2020-10-14
# 2         263   2020-10-14
# 3        1143   2020-07-31
# 4         208   2020-10-26

# %% [markdown]
# Number of Rows and Columns Before Data Cleaning

# %%
wholeData.shape
# Out:
# (3033, 12)

# %%
wholeData.columns
# Out:
# Index(['title', 'genres', 'budget', 'popularity', 'production_companies',
#        'production_countries', 'revenue', 'runtime', 'status', 'vote_avg',
#        'vote_count', 'release_date'],
#       dtype='object')

# %%
wholeData.isnull().sum()
# Out:
# title                   0
# genres                  0
# budget                  0
# popularity              0
# production_companies    0
# production_countries    0
# revenue                 0
# runtime                 0
# status                  0
# vote_avg                0
# vote_count              0
# release_date            0
# dtype: int64

# %% [markdown]
# # Data Cleaning:

# %%
# Changing Data Type of Release Date Into Datetime:

wholeData['release_date'] = pd.to_datetime(wholeData['release_date'])
wholeData['release_date'].head()
# Out:
# 0   2020-11-19
# 1   2020-10-14
# 2   2020-10-14
# 3   2020-07-31
# 4   2020-10-26
# Name: release_date, dtype: datetime64[ns]

# %%
# Budget and Revenue
# Replacing'0' by NaN

wholeData[['budget','revenue']] = wholeData[['budget','revenue']].replace(0,np.NAN)

wholeData.dropna(subset=['budget', 'revenue'], inplace=True)
print('After cleaning, we have {} rows'.format(wholeData.shape[0]))
# Out:
# After cleaning, we have 54 rows

# %%
# Data Imputation
# Profits of each movie

wholeData['profit'] = wholeData['revenue']-wholeData['budget']
wholeData['profit'] = wholeData['profit'].apply(np.int64)
wholeData['budget'] = wholeData['budget'].apply(np.int64)
wholeData['revenue'] = wholeData['revenue'].apply(np.int64)

# %%
wholeData.dtypes
# Out:
# title                           object
# genres                          object
# budget                           int64
# popularity                     float64
# production_companies            object
# production_countries            object
# revenue                          int64
# runtime                          int64
# status                          object
# vote_avg                       float64
# vote_count                       int64
# release_date            datetime64[ns]
# profit                           int64
# dtype: object

# %%
wholeData.head()
# Out:
#                                      title  \
# 17                                    Soul
# 22                              Underwater
# 23  The SpongeBob Movie: Sponge on the Run
# 25                                   Mulan
# 27                                      반도
#
#                                                genres     budget  popularity  \
# 17  [Family, Animation, Comedy, Drama, Music, Fant...  150000000    2322.419
# 22        [Action, Horror, Science Fiction, Thriller]   80000000     464.923
# 23    [Animation, Fantasy, Adventure, Comedy, Family]   60000000     463.955
# 25                               [Adventure, Fantasy]  200000000     441.304
# 27                         [Action, Horror, Thriller]   17000000     403.092
#
#                                  production_companies  \
# 17                      [Walt Disney Pictures, Pixar]
# 22  [Chernin Entertainment, 20th Century Fox, TSG ...
# 23  [United Plankton Pictures, Nickelodeon Movies,...
# 25  [Walt Disney Pictures, China Film Group Corpor...
# 27  [Next Entertainment World, RedPeter Film, Vant...
#
#                        production_countries   revenue  runtime    status  \
# 17               [United States of America]  57400000      102  Released
# 22               [United States of America]  40882928       95  Released
# 23  [South Korea, United States of America]   4700000       95  Released
# 25        [China, United States of America]  57000000      115  Released
# 27                            [South Korea]  39657073      114  Released
#
#     vote_avg  vote_count release_date     profit
# 17       8.3        4397   2020-12-25  -92600000
# 22       6.3        1877   2020-01-08  -39117072
# 23       7.8        1973   2020-08-14  -55300000
# 25       7.1        4202   2020-09-04 -143000000
# 27       7.0        1187   2020-07-15   22657073

# %%
def find_min_max(col_name):
    min_index = wholeData[col_name].idxmin()
    max_index = wholeData[col_name].idxmax()
    #select the lowest and hisghest value from given col_name
    low  = pd.DataFrame(wholeData.loc[min_index,:])
    high = pd.DataFrame(wholeData.loc[max_index,:])
    #Print the results
    
    print('Movie which has highest '+col_name+' : ', wholeData['title'][max_index])
    print('Movie which has lowest '+col_name+' : ', wholeData['title'][min_index])
    return pd.concat([high,low], axis=1)

# %%
def top_10(col_name,size=10):
    #find the all times top 10 for a fiven column
    #sort the given column and select the top 10
    df_sorted = pd.DataFrame(wholeData[col_name].sort_values(ascending=False))[:size]
    df_sorted['title'] = df['title']
    plt.figure(figsize=(12,6))
    #Calculate the avarage
    avg = np.mean(df[col_name])   
    sns.barplot(x=col_name, y='title', data=df_sorted, label=col_name)
    plt.axvline(avg, color='k', linestyle='--', label='mean')
    if (col_name == 'profit' or col_name == 'budget' or col_name == 'revenue'):
        plt.xlabel(col_name.capitalize() + ' (U.S Dolar)')
    else:
        plt.xlabel(col_name.capitalize())
    plt.ylabel('')
    plt.title('Top 10 Movies in: ' + col_name.capitalize())
    plt.legend()

# %%
find_min_max('profit')
# Out:
# Movie which has highest profit :  八佰
# Movie which has lowest profit :  Mulan
#                                                                     398  \
# title                                                                八佰
# genres                                    [War, History, Drama, Action]
# budget                                                         80000000
# popularity                                                        23.42
# production_companies  [Beijing Diqi Yinxiang Entertainment, Huayi Br...
# production_countries                                            [China]
# revenue                                                       460919368
# runtime                                                             147
# status                                                         Released
# vote_avg                                                            7.3
# vote_count                                                           23
# release_date                                        2020-08-14 00:00:00
# profit                                                        380919368
#
#                                                                     25
# title                                                             Mulan
# genres                                             [Adventure, Fantasy]
# budget                                                        200000000
# popularity                                                      441.304
# production_companies  [Walt Disney Pictures, China Film Group Corpor...
# production_countries                  [China, United States of America]
# revenue                                                        57000000
# runtime                                                             115
# status                                                         Released
# vote_avg                                                            7.1
# vote_count                                                         4202
# release_date                                        2020-09-04 00:00:00
# profit                                                       -143000000

# %%
top_10('profit')

# %%
find_min_max('budget')
# Out:
# Movie which has highest budget :  Mulan
# Movie which has lowest budget :  Don’t Touch My Foot
#                                                                      25  \
# title                                                             Mulan
# genres                                             [Adventure, Fantasy]
# budget                                                        200000000
# popularity                                                      441.304
# production_companies  [Walt Disney Pictures, China Film Group Corpor...
# production_countries                  [China, United States of America]
# revenue                                                        57000000
# runtime                                                             115
# status                                                         Released
# vote_avg                                                            7.1
# vote_count                                                         4202
# release_date                                        2020-09-04 00:00:00
# profit                                                       -143000000
#
#                                               63
# title                        Don’t Touch My Foot
# genres                          [Comedy, Action]
# budget                                        10
# popularity                                 1.331
# production_companies                 [Foot News]
# production_countries  [United States of America]
# revenue                                        2
# runtime                                        4
# status                                  Released
# vote_avg                                    10.0
# vote_count                                     1
# release_date                 2020-07-16 00:00:00
# profit                                        -8

# %%
top_10('budget')

# %%
find_min_max('revenue')
# Out:
# Movie which has highest revenue :  八佰
# Movie which has lowest revenue :  Don’t Touch My Foot
#                                                                     398  \
# title                                                                八佰
# genres                                    [War, History, Drama, Action]
# budget                                                         80000000
# popularity                                                        23.42
# production_companies  [Beijing Diqi Yinxiang Entertainment, Huayi Br...
# production_countries                                            [China]
# revenue                                                       460919368
# runtime                                                             147
# status                                                         Released
# vote_avg                                                            7.3
# vote_count                                                           23
# release_date                                        2020-08-14 00:00:00
# profit                                                        380919368
#
#                                              63
# title                        Don’t Touch My Foot
# genres                          [Comedy, Action]
# budget                                        10
# popularity                                 1.331
# production_companies                 [Foot News]
# production_countries  [United States of America]
# revenue                                        2
# runtime                                        4
# status                                  Released
# vote_avg                                    10.0
# vote_count                                     1
# release_date                 2020-07-16 00:00:00
# profit                                        -8

# %%
top_10('revenue')

# %%
find_min_max('runtime')
# Out:
# Movie which has highest runtime :  అల వైకుంఠపురములో
# Movie which has lowest runtime :  From the Depths
#                                                              870  \
# title                                           అల వైకుంఠపురములో
# genres                                           [Action, Drama]
# budget                                                  14000000
# popularity                                                 8.197
# production_companies  [Geetha Arts, Haarika & Hassine Creations]
# production_countries                                     [India]
# revenue                                                 28859072
# runtime                                                      165
# status                                                  Released
# vote_avg                                                     6.4
# vote_count                                                    39
# release_date                                 2020-01-12 00:00:00
# profit                                                  14859072
#
#                                                      863
# title                                    From the Depths
# genres                [Drama, Horror, Thriller, Mystery]
# budget                                               500
# popularity                                         8.243
# production_companies                      [Dual Visions]
# production_countries                                  []
# revenue                                              500
# runtime                                                0
# status                                          Released
# vote_avg                                             6.2
# vote_count                                            26
# release_date                         2020-11-18 00:00:00
# profit                                                 0

# %%
top_10('runtime')

# %%
def plot_correlation_map( wholeData ):
    corr = wholeData.corr()
    _ , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 240 , 10 , as_cmap = True )
    _ = sns.heatmap(corr,cmap = cmap,square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, 
                    annot = True, annot_kws = { 'fontsize' : 12 })

# %%
plot_correlation_map(wholeData[['popularity','budget','revenue','runtime','vote_count']])

# %%
top_10('vote_count', size=30)

# %%
df_related = wholeData[['profit','budget','revenue','runtime', 'vote_count','popularity']]

# %%
sns.pairplot(df_related, kind='reg')
plt.savefig('correlation.png',bbox_inches='tight')
